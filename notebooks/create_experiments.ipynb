# %%
from langgraph.graph import StateGraph,MessagesState,START,END
from langchain_core.messages import SystemMessage, HumanMessage, BaseMessage
from get_llm import get_llm

# %%
#get th llm

llm =  get_llm(model = "gemini-2.5-flash-lite")

#create node
def ask_llm(state:MessagesState):
    role = [SystemMessage(content="You are a Popular web seach application")]
    result = llm.invoke(
        role + state["messages"]
    )
    return {"messages":result}

# %%
graph = StateGraph(MessagesState)

#addnodes
graph.add_node("Ask_llm",ask_llm)

#add edges
graph.set_entry_point("Ask_llm")
graph.set_finish_point("Ask_llm")
graph

# %%
compiled_graph = graph.compile()
response = compiled_graph.invoke({
            "messages":[HumanMessage(content = "Why Gachibowli is named Gachibowli?")]
            }
            )
response["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The name "Gachibowli" has an interesting origin, stemming from the **historical presence of a large mango grove** in the area.
#
# Here's the breakdown:
#
# *   **"Gachi"** is believed to be derived from the Telugu word **"Gachi" (గచ్చి)**, which refers to a **mango tree** or a **mango grove**.
# *   **"Bowli"** is derived from the Telugu word **"Bavi" (బావి)**, meaning a **well**.
#
# Therefore, "Gachibowli" literally translates to **"well in the mango grove"** or **"mango grove well."**
#
# This name reflects the original landscape of the area, which was characterized by abundant mango trees and the presence of wells that were essential for water supply. Over time, as the area developed and urbanized, the name has stuck, even though the mango groves are largely gone.
